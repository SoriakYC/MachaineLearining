# %%
Table[(n + 1)*{Cos[59 \[Degree]*n], Sin[59 \[Degree]*n]}, {n, 0, 
    359}] // N;
Table[Total[lst[[1 ;; n]]], {n, Length[lst]}] // ListLinePlot
# Out:
# -Graphics-

# %%
Plot[Sin[x],{x,9,20}]
# Out:
# -Graphics-
